# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
os.chdir('F:\TopMentor_DataScience\Batch 103 Day 38')
df=pd.read_csv('prisoners.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 6 columns):
#  #   Column                                             Non-Null Count  Dtype
# ---  ------                                             --------------  -----
#  0   STATE/UT                                           35 non-null     object
#  1   YEAR                                               35 non-null     int64
#  2   No. of Inmates benefitted by Elementary Education  35 non-null     int64
#  3   No. of Inmates benefitted by Adult Education       35 non-null     int64
#  4   No. of Inmates benefitted by Higher Education      35 non-null     int64
#  5   No. of Inmates benefitted by Computer Course       35 non-null     int64
# dtypes: int64(5), object(1)
# memory usage: 1.8+ KB

# %%
df.isnull().sum()
# Out:
# STATE/UT                                             0
# YEAR                                                 0
# No. of Inmates benefitted by Elementary Education    0
# No. of Inmates benefitted by Adult Education         0
# No. of Inmates benefitted by Higher Education        0
# No. of Inmates benefitted by Computer Course         0
# dtype: int64

# %%
df2=df.iloc[:,:]
df2['YEAR'].astype('str')
df2.head()
# Out:
#             STATE/UT  YEAR  No. of Inmates benefitted by Elementary Education  \
# 0     Andhra Pradesh  2013                                               9480
# 1  Arunachal Pradesh  2013                                                  0
# 2              Assam  2013                                                676
# 3              Bihar  2013                                               1693
# 4        Chhatisgarh  2013                                               1664
#
#    No. of Inmates benefitted by Adult Education  \
# 0                                         13758
# 1                                             0
# 2                                           750
# 3                                          3013
# 4                                          1803
#
#    No. of Inmates benefitted by Higher Education  \
# 0                                            672
# 1                                              0
# 2                                             14
# ...

# %%
df2['Total']=df2.sum(axis=1, skipna=True, numeric_only=True, min_count=0)
df2.tail()
# Out:
#         STATE/UT  YEAR  No. of Inmates benefitted by Elementary Education  \
# 30  D & N Haveli  2013                                                  0
# 31   Daman & Diu  2013                                                  0
# 32         Delhi  2013                                               1458
# 33   Lakshadweep  2013                                                  0
# 34   Pondicherry  2013                                                  0
#
#     No. of Inmates benefitted by Adult Education  \
# 30                                             0
# 31                                             0
# 32                                          1187
# 33                                             0
# 34                                             0
#
#     No. of Inmates benefitted by Higher Education  \
# 30                                              0
# 31                                              0
# 32                                            908
# ...

# %%
#df2_column=df2.append(Column_totals,ignore_index=True)
#df2_Total=pd.concat([df2,df2['Total']],axis=1)
#df2_Total
#df2

# %%
df2_columnTotal=df2.sum(numeric_only=True)
df2_columnTotal
# Out:
# YEAR                                                  70455
# No. of Inmates benefitted by Elementary Education     37027
# No. of Inmates benefitted by Adult Education          53720
# No. of Inmates benefitted by Higher Education          8311
# No. of Inmates benefitted by Computer Course           7356
# Total                                                176869
# dtype: int64

# %%
#pd.DataFrame(df2_columnTotal).T

# %%
df2_final=pd.DataFrame(df2_columnTotal).T
df2_final.index=['Column Totals']

# %%
#df2['No. of Inmates benefitted by Elementary Education'].sum()

# %%
df1=pd.concat([df2,df2_final],ignore_index=False)

#df1.index.names='State'
df1
# Out:
#                         STATE/UT   YEAR  \
# 0                 Andhra Pradesh   2013
# 1              Arunachal Pradesh   2013
# 2                          Assam   2013
# 3                          Bihar   2013
# 4                    Chhatisgarh   2013
# 5                            Goa   2013
# 6                        Gujarat   2013
# 7                        Haryana   2013
# 8               Himachal Pradesh   2013
# 9                Jammu & Kashmir   2013
# 10                     Jharkhand   2013
# 11                     Karnataka   2013
# 12                        Kerala   2013
# 13                Madhya Pradesh   2013
# 14                   Maharashtra   2013
# 15                       Manipur   2013
# 16                     Meghalaya   2013
# 17                       Mizoram   2013
# 18                      Nagaland   2013
# 19                        Orissa   2013
# 20                        Punjab   2013
# 21                     Rajasthan   2013
# ...

# %%
x=df1.iloc[:,0:2].values
#x.set_index='State'
#y=df2.iloc[:,:-1]
#print(y)
x
# Out:
# array([['Andhra Pradesh', 2013],
#        ['Arunachal Pradesh', 2013],
#        ['Assam', 2013],
#        ['Bihar', 2013],
#        ['Chhatisgarh', 2013],
#        ['Goa', 2013],
#        ['Gujarat', 2013],
#        ['Haryana', 2013],
#        ['Himachal Pradesh', 2013],
#        ['Jammu & Kashmir', 2013],
#        ['Jharkhand', 2013],
#        ['Karnataka', 2013],
#        ['Kerala', 2013],
#        ['Madhya Pradesh', 2013],
#        ['Maharashtra', 2013],
#        ['Manipur', 2013],
#        ['Meghalaya', 2013],
#        ['Mizoram', 2013],
#        ['Nagaland', 2013],
#        ['Orissa', 2013],
#        ['Punjab', 2013],
#        ['Rajasthan', 2013],
#        ['Sikkim', 2013],
#        ['Tamilnadu', 2013],
#        ['Tripura', 2013],
#        ['Uttar Pradesh', 2013],
#        ['Uttaranchal', 2013],
#        ['West Bengal', 2013],
#        ['A & N Islands', 2013],
#        ['Chandigarh', 2013],
#        ['D & N Haveli', 2013],
#        ['Daman & Diu', 2013],
# ...

# %%
import matplotlib.pyplot as plt
x[]
# Out:
#   Cell In[164], line 2
#     x[]
#       ^
# SyntaxError: invalid syntax

# %%
plt.plot(kind='bar')
plt.xlabel(x[])
plt.ylabel(x['YEAR'])
plt.show()
